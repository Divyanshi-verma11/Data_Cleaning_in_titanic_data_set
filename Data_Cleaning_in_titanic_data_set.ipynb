# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
data = sns.load_dataset("titanic")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.shape
# Out:
# (891, 15)

# %% [markdown]
# # sum of total null value

# %%
x = data.isnull().sum().sum()
x
# Out:
# 869

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # percentage null_value

# %%
a = (data.isnull().sum()*100)/len(data)
a
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# # percentage of no. of total null value in the data

# %%
per_isnull = (x * 100) / (len(data) * len(data.columns) )
per_isnull
# Out:
# 6.502057613168724

# %%
y = data.notnull().sum()
y
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
per_notnull = ((y * 100) / (len(data) * len(data.columns))).sum()
per_notnull
# Out:
# 93.49794238683128

# %% [markdown]
# # heatmap representation of null and not null data

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
sns.heatmap(data.notnull(), vmin = 0, vmax = 1)
plt.show()

# %% [markdown]
# # drop and delete missing value

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data = pd.read_csv("titanic.csv")
data.drop(columns = ["deck"], axis = 0, inplace = True)

# %%
data.shape
# Out:
# (891, 14)

# %%
data.isnull().sum().sum()
# Out:
# 181

# %%
data.dropna().isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data.dropna(how = "any", inplace = True)
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
data.shape
# Out:
# (712, 14)

# %% [markdown]
# # percentage of total row after drop

# %%
((891 - 712)* 100)/891
# Out:
# 20.089786756453424

# %% [markdown]
# # fill the missing content in the data

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.fillna("python") #wrong way to fill the data
# Out:
#      survived  pclass     sex     age  sibsp  parch     fare embarked   class  \
# 0           0       3    male    22.0      1      0   7.2500        S   Third
# 1           1       1  female    38.0      1      0  71.2833        C   First
# 2           1       3  female    26.0      0      0   7.9250        S   Third
# 3           1       1  female    35.0      1      0  53.1000        S   First
# 4           0       3    male    35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...     ...    ...    ...      ...      ...     ...
# 886         0       2    male    27.0      0      0  13.0000        S  Second
# 887         1       1  female    19.0      0      0  30.0000        S   First
# 888         0       3  female  python      1      2  23.4500        S   Third
# 889         1       1    male    26.0      0      0  30.0000        C   First
# 890         0       3    male    32.0      0      0   7.7500        Q   Third
#
# ...

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
# data.fillna(method = "ffill")
data.ffill()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  19.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.bfill()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  26.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data["age"].fillna(data["age"].mode()[0], inplace = True)
data
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3367630571.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["age"].fillna(data["age"].mode()[0], inplace = True)
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# ...

# %%
data.mode()

for i in range(0, len(data.columns)):
    x = data.columns[i]
    y = (data.iloc[0, i])
    data[x].fillna(y, inplace = True)
data
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\1310099522.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[x].fillna(y, inplace = True)
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# ...

# %%
for i in data.select_dtypes(include="object").columns:
    data[i].fillna(data[i].mode()[0], inplace = True)
data
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\2542631843.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].mode()[0], inplace = True)
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# ...

# %%
for i in data.select_dtypes(include = ["float64", "int64"]).columns:
    data[i].fillna(data[i].mean(), inplace = True)
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3711410937.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].mean(), inplace = True)

# %% [markdown]
# # scikit-learn

# %%
data = pd.read_csv("titanic.csv")
data.drop(columns = "deck", inplace = True)
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(6)
# memory usage: 85.4+ KB

# %%
data.select_dtypes(include = ["float64", "int64"]).columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = "mean")
ar = si.fit_transform(data[['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']])
new_data = pd.DataFrame(ar, columns = ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'])
new_data
# Out:
#      survived  pclass        age  sibsp  parch     fare
# 0         0.0     3.0  22.000000    1.0    0.0   7.2500
# 1         1.0     1.0  38.000000    1.0    0.0  71.2833
# 2         1.0     3.0  26.000000    0.0    0.0   7.9250
# 3         1.0     1.0  35.000000    1.0    0.0  53.1000
# 4         0.0     3.0  35.000000    0.0    0.0   8.0500
# ..        ...     ...        ...    ...    ...      ...
# 886       0.0     2.0  27.000000    0.0    0.0  13.0000
# 887       1.0     1.0  19.000000    0.0    0.0  30.0000
# 888       0.0     3.0  29.699118    1.0    2.0  23.4500
# 889       1.0     1.0  26.000000    0.0    0.0  30.0000
# 890       0.0     3.0  32.000000    0.0    0.0   7.7500
#
# [891 rows x 6 columns]

# %%
new_data.isnull().sum()
# Out:
# survived    0
# pclass      0
# age         0
# sibsp       0
# parch       0
# fare        0
# dtype: int64

# %%
def conv(value):
    if (value == "man"):
        return 0
    else:
        return 1

data.insert(1, "age1", data["who"].apply(conv))
data
# Out:
#      survived  age1  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0     0       3    male  22.0      1      0   7.2500        S
# 1           1     1       1  female  38.0      1      0  71.2833        C
# 2           1     1       3  female  26.0      0      0   7.9250        S
# 3           1     1       1  female  35.0      1      0  53.1000        S
# 4           0     0       3    male  35.0      0      0   8.0500        S
# ..        ...   ...     ...     ...   ...    ...    ...      ...      ...
# 886         0     0       2    male  27.0      0      0  13.0000        S
# 887         1     1       1  female  19.0      0      0  30.0000        S
# 888         0     1       3  female   NaN      1      2  23.4500        S
# 889         1     0       1    male  26.0      0      0  30.0000        C
# 890         0     0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# # seperate the data of sex and who into two parts (ordinal data)

# %% [markdown]
# # using pandas

# %%
data_dum = data[["sex", "who"]]
data_dum
# Out:
#         sex    who
# 0      male    man
# 1    female  woman
# 2    female  woman
# 3    female  woman
# 4      male    man
# ..      ...    ...
# 886    male    man
# 887  female  woman
# 888  female  woman
# 889    male    man
# 890    male    man
#
# [891 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# survived         0
# age1             0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data = pd.get_dummies(data_dum)
data
# Out:
#      sex_female  sex_male  who_child  who_man  who_woman
# 0         False      True      False     True      False
# 1          True     False      False    False       True
# 2          True     False      False    False       True
# 3          True     False      False    False       True
# 4         False      True      False     True      False
# ..          ...       ...        ...      ...        ...
# 886       False      True      False     True      False
# 887        True     False      False    False       True
# 888        True     False      False    False       True
# 889       False      True      False     True      False
# 890       False      True      False     True      False
#
# [891 rows x 5 columns]

# %%
def conv(value):
    if(value == True):
        return 1
    else:
        return 0

# %%
l = ["sex_female", "sex_male", "who_child", "who_man", "who_woman"]
for i in l:
    data[i] = data[i].apply(conv)
data
# Out:
#      sex_female  sex_male  who_child  who_man  who_woman
# 0             0         1          0        1          0
# 1             1         0          0        0          1
# 2             1         0          0        0          1
# 3             1         0          0        0          1
# 4             0         1          0        1          0
# ..          ...       ...        ...      ...        ...
# 886           0         1          0        1          0
# 887           1         0          0        0          1
# 888           1         0          0        0          1
# 889           0         1          0        1          0
# 890           0         1          0        1          0
#
# [891 rows x 5 columns]

# %% [markdown]
# # using scikit-learn

# %%
from sklearn.preprocessing import OneHotEncoder
h = OneHotEncoder()
a = h.fit_transform(data_dum).toarray()
pd.DataFrame(a, columns = ["sex_female", "sex_male", "who_child", "who_man", "who_woman"], dtype = "int")
# Out:
#      sex_female  sex_male  who_child  who_man  who_woman
# 0             0         1          0        1          0
# 1             1         0          0        0          1
# 2             1         0          0        0          1
# 3             1         0          0        0          1
# 4             0         1          0        1          0
# ..          ...       ...        ...      ...        ...
# 886           0         1          0        1          0
# 887           1         0          0        0          1
# 888           1         0          0        0          1
# 889           0         1          0        1          0
# 890           0         1          0        1          0
#
# [891 rows x 5 columns]

# %% [markdown]
# # drop the first columns of common data

# %%
from sklearn.preprocessing import OneHotEncoder
h = OneHotEncoder(drop = "first")
a = h.fit_transform(data_dum).toarray()
pd.DataFrame(a, columns = ["sex_male", "who_man", "who_woman"], dtype = "int")
# Out:
#      sex_male  who_man  who_woman
# 0           1        1          0
# 1           0        0          1
# 2           0        0          1
# 3           0        0          1
# 4           1        1          0
# ..        ...      ...        ...
# 886         1        1          0
# 887         0        0          1
# 888         0        0          1
# 889         1        1          0
# 890         1        1          0
#
# [891 rows x 3 columns]

# %% [markdown]
# # label encoding perform on nominal data

# %%
dataset = pd.DataFrame({"Name" : ["divyanshu", "himanshu", "chetna", "priya", "sakshi"]})
dataset
# Out:
#         Name
# 0  divyanshu
# 1   himanshu
# 2     chetna
# 3      priya
# 4     sakshi

# %%
from sklearn.preprocessing import LabelEncoder 
l = LabelEncoder()
dataset["e"] = l.fit_transform(dataset["Name"])

# %%
dataset
# Out:
#         Name  e
# 0  divyanshu  1
# 1   himanshu  2
# 2     chetna  0
# 3      priya  3
# 4     sakshi  4

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
l = LabelEncoder()
data["embark_town_no."] = l.fit_transform(data["embark_town"])
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # ordinal encoding

# %%
a = pd.DataFrame({"size" : ["s", "l", "m", "l", "xl", "m", "s", "s", "l", "m", "l", "xl", "m", "s"]})
a
# Out:
#    size
# 0     s
# 1     l
# 2     m
# 3     l
# 4    xl
# 5     m
# 6     s
# 7     s
# 8     l
# 9     m
# 10    l
# 11   xl
# 12    m
# 13    s

# %%
data = [["s", "m", "l", "xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
O = OrdinalEncoder(categories=data)
# O.fit_transform(a)
O.fit(a[["size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
a['size_new'] = O.transform(a[["size"]])

# %%
a
# Out:
#    size  size_new
# 0     s       0.0
# 1     l       2.0
# 2     m       1.0
# 3     l       2.0
# 4    xl       3.0
# 5     m       1.0
# 6     s       0.0
# 7     s       0.0
# 8     l       2.0
# 9     m       1.0
# 10    l       2.0
# 11   xl       3.0
# 12    m       1.0
# 13    s       0.0

# %% [markdown]
# # map function

# %%
data_order = {"s" : 0, "m" : 1, "l" : 2, "xl" : 3}
a["size_map"] = a["size"].map(data_order)
a
# Out:
#    size  size_new  size_map
# 0     s       0.0         0
# 1     l       2.0         2
# 2     m       1.0         1
# 3     l       2.0         2
# 4    xl       3.0         3
# 5     m       1.0         1
# 6     s       0.0         0
# 7     s       0.0         0
# 8     l       2.0         2
# 9     m       1.0         1
# 10    l       2.0         2
# 11   xl       3.0         3
# 12    m       1.0         1
# 13    s       0.0         0

# %%
a = pd.read_csv("titanic.csv")
a["embark_town"].fillna(a["embark_town"].mode()[0], inplace = True)
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\2264903054.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a["embark_town"].fillna(a["embark_town"].mode()[0], inplace = True)

# %%
from sklearn.preprocessing import OrdinalEncoder
data_set = [["Southampton","Cherbourg", "Queenstown"]]
o = OrdinalEncoder(categories = data_set)
o.fit(a[["embark_town"]])
# Out:
# OrdinalEncoder(categories=[['Southampton', 'Cherbourg', 'Queenstown']])

# %%
a["new_embark_town"] = o.transform(a[["embark_town"]])
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
dataset = {"Southampton" : 1, "Cherbourg" : 2, "Queenstown" : 3}
a["embark_town_new"] = a["embark_town"].map(dataset)
a.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  new_embark_town  \
# 0    man        True  NaN  Southampton    no  False              0.0
# 1  woman       False    C    Cherbourg   yes  False              1.0
# 2  woman       False  NaN  Southampton   yes   True              0.0
# 3  woman       False    C  Southampton   yes  False              0.0
# 4    man        True  NaN  Southampton    no   True              0.0
#
#    embark_town_new
# 0                1
# 1                2
# 2                1
# 3                1
# ...

# %% [markdown]
# # outlier of the data

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(x = "fare", data = data)
plt.show()

# %% [markdown]
# # quantile

# %%
q1 = data["fare"].quantile(0.25)
q3 = data["fare"].quantile(0.75)
IQR = q3 - q1
IQR
# Out:
# 23.0896

# %%
# np.percentile(data["fare"], 25)
# sns.kdeplot(x = "fare", data = data)
sns.distplot(data["fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\1193552724.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["fare"])

# %%
min = q1 - (1.5 * IQR)
max = q3 + (1.5 * IQR)
min, max
# Out:
# (-26.724, 65.6344)

# %%
data1 = data[data["fare"] <= max]
data1.shape
# Out:
# (775, 15)

# %%
sns.boxplot(x = "fare", data = data1)
plt.show()

# %%
# np.percentile(data["fare"], 25)
# sns.kdeplot(x = "fare", data = data1)
sns.distplot(data1["fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\1774751503.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1["fare"])

# %% [markdown]
# # z type

# %%
data = pd.read_csv("titanic.csv")
new_data = (data["fare"] - np.mean(data["fare"]))/np.std(data["fare"])
new_data
data["new_fare"] = new_data

data_new = data[data["new_fare"] <= 3]
data_new
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
sns.boxplot(x = "new_fare", data = data_new)
plt.show()

# %%
data = pd.read_csv("titanic.csv")
min_range = np.mean(data["fare"]) - (3 * np.std(data["fare"]))
max_range = np.mean(data["fare"]) + (3 * np.std(data["fare"]))
min_range, max_range
# Out:
# (-116.79239536574771, 181.20081130289697)

# %%
new_data = data[data["fare"] <= max_range]
new_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x = "fare", data = new_data)
plt.show()

# %% [markdown]
# # feature scaling technique

# %% [markdown]
# # standardization

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data["fare"].isnull().sum()
# Out:
# 0

# %%
new_data = ((data["fare"] - np.mean(data["fare"]))/np.std(data["fare"]))
data["new_fare"] = new_data
new_data.describe()
# Out:
# count    8.910000e+02
# mean    -7.974666e-18
# std      1.000562e+00
# min     -6.484217e-01
# 25%     -4.891482e-01
# 50%     -3.573909e-01
# 75%     -2.424635e-02
# max      9.667167e+00
# Name: fare, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title("After")
sns.distplot(data["new_fare"])

plt.subplot(1, 2, 2)
plt.title("before")
sns.distplot(data["fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3356613417.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["new_fare"])
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3356613417.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["fare"])

# %% [markdown]
# # using scikit_learn

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(data[["fare"]])
# Out:
# StandardScaler()

# %%
new_data = sc.transform(data[["fare"]])
data["new_fare"] = new_data
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title("After")
sns.distplot(data["new_fare"])

plt.subplot(1, 2, 2)
plt.title("before")
sns.distplot(data["fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3356613417.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["new_fare"])
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\3356613417.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["fare"])

# %% [markdown]
# # normalization technique

# %% [markdown]
# # min max algorithm

# %%
data = pd.read_csv("titanic.csv")
new_fare = (data["fare"] - np.min(data["fare"])) / (np.max(data["fare"])-np.min(data["fare"]))
data["new_fare"] = new_fare
new_fare
# Out:
# 0      0.014151
# 1      0.139136
# 2      0.015469
# 3      0.103644
# 4      0.015713
#          ...
# 886    0.025374
# 887    0.058556
# 888    0.045771
# 889    0.058556
# 890    0.015127
# Name: fare, Length: 891, dtype: float64

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1,2,2)
plt.title("After")
sns.distplot(data["fare"])

plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data["new_fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\243193343.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["fare"])
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\243193343.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["new_fare"])

# %% [markdown]
# # using scikit_learn library

# %%
from sklearn.preprocessing import MinMaxScaler
n = MinMaxScaler()
n.fit(data[["fare"]])
new_fare = n.transform(data[["fare"]])
data["new_fare"] = new_fare

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1,2,2)
plt.title("After")
sns.distplot(data["fare"])

plt.subplot(1,2,1)
plt.title("before")
sns.distplot(data["new_fare"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\243193343.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["fare"])
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\243193343.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["new_fare"])

# %% [markdown]
# # duplicate remover

# %%
b = data["fare"].duplicated().sum()
b
# Out:
# 643

# %%
data.drop_duplicates(keep = "first", inplace = True)

# %%
len(data)
# Out:
# 784

# %% [markdown]
# # replace and change datatype

# %%
from sklearn.impute import SimpleImputer
s = SimpleImputer(strategy = "mean")
new_age = s.fit_transform(data[["age"]])

# %%
new_age1 = new_age.astype("int64")
data["new_age"] = new_age1

# %%
data["age"].value_counts()
# Out:
# age
# 24.00    29
# 18.00    25
# 22.00    24
# 19.00    23
# 28.00    22
#          ..
# 36.50     1
# 0.92      1
# 23.50     1
# 55.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
# ...

# %% [markdown]
# # function tansformation

# %% [markdown]
# #used to convert non-normal distribution data into normal distribution

# %%
sns.distplot(data["new_age"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\574550205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["new_age"])

# %%
sns.boxplot(x = data["new_age"], data = data)
plt.show()

# %%
z = (data["new_age"] - np.mean(data["new_age"])) / np.std(data["new_age"])
new_data = data[z <= 3]
new_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
# ...

# %%
sns.boxplot(x = data["new_age"], data = new_data)
plt.show()

# %%
from sklearn.preprocessing import FunctionTransformer
f = FunctionTransformer(func = np.log1p)
f.fit(new_data[["new_age"]])
new_data["new_age2"] = f.transform(data[["new_age"]])
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\883179745.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["new_age2"] = f.transform(data[["new_age"]])

# %%
sns.distplot(new_data["new_age2"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\243931545.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data["new_age2"])

# %%
(new_data["new_age2"]).median(),(new_data["new_age2"]).mode(),(new_data["new_age2"]).mean()
# Out:
# (3.4011973816621555,
#  0    3.401197
#  Name: new_age2, dtype: float64,
#  3.269448225405493)

# %%
from sklearn.preprocessing import FunctionTransformer
f = FunctionTransformer(func = lambda x : x ** 2)
f.fit(new_data[["new_age"]])
new_data["new_age2"] = f.transform(data[["new_age"]])
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\875915516.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["new_age2"] = f.transform(data[["new_age"]])

# %%
sns.distplot(new_data["new_age2"])
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_5960\2644137664.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data["new_age2"])

# %%
(new_data["new_age2"]).median(),(new_data["new_age2"]).mode(),(new_data["new_age2"]).mean()
# Out:
# (841.0,
#  0    841
#  Name: new_age2, dtype: int64,
#  1049.9)

# %% [markdown]
# # Thank you
